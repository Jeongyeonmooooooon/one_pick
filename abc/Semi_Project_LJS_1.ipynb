# %%
from pandas import Series, DataFrame
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %matplotlib inline
plt.rcParams["figure.figsize"] = [12,6]

# %%
df = pd.read_csv('C:\\Users\Ente_LJS\\Anaconda_src\\Semi_Project_1pick\\train1.csv', encoding='ANSI')
df
# Out:
#                 Id    idhogar  parentesco1  hhsize      v2a1  hacdor  rooms  \
# 0     ID_279628684  21eb7fcc1            1       1  190000.0       0      3
# 1     ID_f29eb3ddd  0e5d7a658            1       1  135000.0       0      4
# 2     ID_68de51c94  2c7317ea8            1       1       NaN       0      8
# 3     ID_d671db89c  2b58d945f            0       4  180000.0       0      5
# 4     ID_d56d6f5f5  2b58d945f            0       4  180000.0       0      5
# 5     ID_ec05b1a7b  2b58d945f            1       4  180000.0       0      5
# 6     ID_e9e0c1100  2b58d945f            0       4  180000.0       0      5
# 7     ID_3e04e571e  d6dae86b7            0       4  130000.0       1      2
# 8     ID_1284f8aad  d6dae86b7            1       4  130000.0       1      2
# 9     ID_51f52fdd2  d6dae86b7            0       4  130000.0       1      2
# 10    ID_db44f5c59  d6dae86b7            0       4  130000.0       1      2
# ...

# %% [markdown]
# ## 컬럼 해석

# %% [markdown]
# #### 값이 10 넘어가는 case
#
# - v2a1 : 집세. nan값 포함
# - escolari : 교육년수
# - dependency : 19이하 64이상자 / 19~64살
# - edjefe : 남자 세대주 교육년수
# - edjefa : 여자 세대주 교육년수
# - meaneduc : 같은세대 19이상 교육년수 평균
# - age : 나이
# - SQBescolari : 교육년수 제곱
# - SQBage : 나이 제곱
# - SQBhogar_total : 총 세대원 제곱
# - SQBovercrowding : overcrowding(인원/방개수) 제곱

# %% [markdown]
# #### 특이값 포함하는 case
# - v2a1 : 집세. nan값 포함
# - v18q : 타블릿 가진 경우 1, 없으면 nan
# - rez_esc : Years behind in school.꿇은 년수. nan값 포함
# - dependecy : 19이하 64이상자 / 19~64살.  yes/no값 포함
# - edjefe : 남자 세대주 교육년수. yes/no값 포함
# - edjefa : 여자 세대주 교육년수. yes/no값 포함
